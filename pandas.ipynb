# %% [markdown]
# # Pandas and its Basics

# %%
import pandas as pd

# %%
data=pd.Series([1,2,3,4,5])
print(data)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
print(type(data))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(type(data.values))
# Out:
# <class 'numpy.ndarray'>

# %%
data.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
data_custom_index=pd.Series([10,20,30],index=['sanidhya','abc','xyz'])
print(data_custom_index)

print(data_custom_index['sanidhya'])
# Out:
# sanidhya    10
# abc         20
# xyz         30
# dtype: int64
# 10

# %%
df=pd.read_csv('digital.csv')

print(df)
# Out:
#       CustomerID  Age  Gender  Income CampaignChannel   CampaignType  \
# 0           8000   56  Female  136912    Social Media      Awareness
# 1           8001   69    Male   41760           Email      Retention
# 2           8002   46  Female   88456             PPC      Awareness
# 3           8003   32  Female   44085             PPC     Conversion
# 4           8004   60  Female   83964             PPC     Conversion
# ...          ...  ...     ...     ...             ...            ...
# 7995       15995   21    Male   24849           Email      Awareness
# 7996       15996   43  Female   44718             SEO      Retention
# 7997       15997   28  Female  125471        Referral  Consideration
# 7998       15998   19  Female  107862             PPC  Consideration
# 7999       15999   31  Female   93002           Email      Awareness
#
#           AdSpend  ClickThroughRate  ConversionRate  WebsiteVisits  \
# 0     6497.870068          0.043919        0.088031              0
# ...

# %%
df.head()
# Out:
#    CustomerID  Age  Gender  Income CampaignChannel CampaignType      AdSpend  \
# 0        8000   56  Female  136912    Social Media    Awareness  6497.870068
# 1        8001   69    Male   41760           Email    Retention  3898.668606
# 2        8002   46  Female   88456             PPC    Awareness  1546.429596
# 3        8003   32  Female   44085             PPC   Conversion   539.525936
# 4        8004   60  Female   83964             PPC   Conversion  1678.043573
#
#    ClickThroughRate  ConversionRate  WebsiteVisits  PagesPerVisit  TimeOnSite  \
# 0          0.043919        0.088031              0       2.399017    7.396803
# 1          0.155725        0.182725             42       2.917138    5.352549
# 2          0.277490        0.076423              2       8.223619   13.794901
# 3          0.137611        0.088004             47       4.540939   14.688363
# 4          0.252851        0.109940              0       2.046847   13.993370
#
# ...

# %%
df.head(10)
# Out:
#    CustomerID  Age  Gender  Income CampaignChannel CampaignType      AdSpend  \
# 0        8000   56  Female  136912    Social Media    Awareness  6497.870068
# 1        8001   69    Male   41760           Email    Retention  3898.668606
# 2        8002   46  Female   88456             PPC    Awareness  1546.429596
# 3        8003   32  Female   44085             PPC   Conversion   539.525936
# 4        8004   60  Female   83964             PPC   Conversion  1678.043573
# 5        8005   25  Female   42925    Social Media    Awareness  9579.388247
# 6        8006   38  Female   25615        Referral    Awareness  7302.899852
# 7        8007   56  Female   57083    Social Media   Conversion  5324.283667
# 8        8008   36  Female  140788           Email    Retention  9421.250951
# 9        8009   40    Male  130764    Social Media    Awareness  6229.193333
#
#    ClickThroughRate  ConversionRate  WebsiteVisits  PagesPerVisit  TimeOnSite  \
# ...

# %%
df.tail()
# Out:
#       CustomerID  Age  Gender  Income CampaignChannel   CampaignType  \
# 7995       15995   21    Male   24849           Email      Awareness
# 7996       15996   43  Female   44718             SEO      Retention
# 7997       15997   28  Female  125471        Referral  Consideration
# 7998       15998   19  Female  107862             PPC  Consideration
# 7999       15999   31  Female   93002           Email      Awareness
#
#           AdSpend  ClickThroughRate  ConversionRate  WebsiteVisits  \
# 7995  8518.308575          0.243792        0.116773             23
# 7996  1424.613446          0.236740        0.190061             49
# 7997  4609.534635          0.056526        0.133826             35
# 7998  9476.106354          0.023961        0.138386             49
# 7999  7743.627070          0.185670        0.057228             15
#
#       PagesPerVisit  TimeOnSite  SocialShares  EmailOpens  EmailClicks  \
# 7995       9.693602   14.227794            70          13            6
# ...

# %%
df.tail(10)
# Out:
#       CustomerID  Age  Gender  Income CampaignChannel   CampaignType  \
# 7990       15990   43  Female   84823    Social Media  Consideration
# 7991       15991   62  Female   69289             SEO      Retention
# 7992       15992   37    Male  138422        Referral      Retention
# 7993       15993   20    Male  120271    Social Media      Retention
# 7994       15994   69  Female  124883        Referral      Awareness
# 7995       15995   21    Male   24849           Email      Awareness
# 7996       15996   43  Female   44718             SEO      Retention
# 7997       15997   28  Female  125471        Referral  Consideration
# 7998       15998   19  Female  107862             PPC  Consideration
# 7999       15999   31  Female   93002           Email      Awareness
#
#           AdSpend  ClickThroughRate  ConversionRate  WebsiteVisits  \
# 7990   880.905233          0.070984        0.097500             12
# 7991  6118.863881          0.240393        0.047079             39
# ...

# %%
df.iloc[:6]
# Out:
#    CustomerID  Age  Gender  Income CampaignChannel CampaignType      AdSpend  \
# 0        8000   56  Female  136912    Social Media    Awareness  6497.870068
# 1        8001   69    Male   41760           Email    Retention  3898.668606
# 2        8002   46  Female   88456             PPC    Awareness  1546.429596
# 3        8003   32  Female   44085             PPC   Conversion   539.525936
# 4        8004   60  Female   83964             PPC   Conversion  1678.043573
# 5        8005   25  Female   42925    Social Media    Awareness  9579.388247
#
#    ClickThroughRate  ConversionRate  WebsiteVisits  PagesPerVisit  TimeOnSite  \
# 0          0.043919        0.088031              0       2.399017    7.396803
# 1          0.155725        0.182725             42       2.917138    5.352549
# 2          0.277490        0.076423              2       8.223619   13.794901
# 3          0.137611        0.088004             47       4.540939   14.688363
# ...

# %%
df.loc[df['Gender']=='Female',['CustomerID','Gender','Income']]
# Out:
#       CustomerID  Gender  Income
# 0           8000  Female  136912
# 2           8002  Female   88456
# 3           8003  Female   44085
# 4           8004  Female   83964
# 5           8005  Female   42925
# ...          ...     ...     ...
# 7994       15994  Female  124883
# 7996       15996  Female   44718
# 7997       15997  Female  125471
# 7998       15998  Female  107862
# 7999       15999  Female   93002
#
# [4839 rows x 3 columns]

# %%
df.loc[0,'Income']=None

df.head()
# Out:
#    CustomerID  Age  Gender   Income CampaignChannel CampaignType      AdSpend  \
# 0        8000   56  Female      NaN    Social Media    Awareness  6497.870068
# 1        8001   69    Male  41760.0           Email    Retention  3898.668606
# 2        8002   46  Female  88456.0             PPC    Awareness  1546.429596
# 3        8003   32  Female  44085.0             PPC   Conversion   539.525936
# 4        8004   60  Female  83964.0             PPC   Conversion  1678.043573
#
#    ClickThroughRate  ConversionRate  WebsiteVisits  PagesPerVisit  TimeOnSite  \
# 0          0.043919        0.088031              0       2.399017    7.396803
# 1          0.155725        0.182725             42       2.917138    5.352549
# 2          0.277490        0.076423              2       8.223619   13.794901
# 3          0.137611        0.088004             47       4.540939   14.688363
# 4          0.252851        0.109940              0       2.046847   13.993370
#
# ...

# %%
df['Income'].fillna(df['Income'].median(),inplace=True)

df.head()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_5272\3475370876.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Income'].fillna(df['Income'].median(),inplace=True)
#    CustomerID  Age  Gender   Income CampaignChannel CampaignType      AdSpend  \
# 0        8000   56  Female  84926.0    Social Media    Awareness  6497.870068
# 1        8001   69    Male  41760.0           Email    Retention  3898.668606
# 2        8002   46  Female  88456.0             PPC    Awareness  1546.429596
# ...

# %%
#Print all the rows with income < 40000

df.loc[df['Income']<40000]
# Out:
#       CustomerID  Age  Gender   Income CampaignChannel   CampaignType  \
# 6           8006   38  Female  25615.0        Referral      Awareness
# 11          8011   28    Male  29605.0             SEO      Awareness
# 15          8015   41  Female  39192.0           Email      Awareness
# 16          8016   20  Female  23331.0             PPC     Conversion
# 28          8028   61  Female  27549.0        Referral      Retention
# ...          ...  ...     ...      ...             ...            ...
# 7968       15968   66    Male  33979.0           Email      Awareness
# 7971       15971   33  Female  20357.0    Social Media      Retention
# 7977       15977   23  Female  30796.0        Referral     Conversion
# 7987       15987   31  Female  24447.0        Referral  Consideration
# 7995       15995   21    Male  24849.0           Email      Awareness
#
#           AdSpend  ClickThroughRate  ConversionRate  WebsiteVisits  \
# ...

# %%
#Print all the female employees whose income is less than 40000

df.loc[(df['Income']<40000) & (df['Gender']=="Female")]
# Out:
#       CustomerID  Age  Gender   Income CampaignChannel   CampaignType  \
# 6           8006   38  Female  25615.0        Referral      Awareness
# 15          8015   41  Female  39192.0           Email      Awareness
# 16          8016   20  Female  23331.0             PPC     Conversion
# 28          8028   61  Female  27549.0        Referral      Retention
# 41          8041   54  Female  25833.0    Social Media     Conversion
# ...          ...  ...     ...      ...             ...            ...
# 7951       15951   29  Female  33054.0        Referral      Awareness
# 7956       15956   43  Female  34413.0             PPC      Awareness
# 7971       15971   33  Female  20357.0    Social Media      Retention
# 7977       15977   23  Female  30796.0        Referral     Conversion
# 7987       15987   31  Female  24447.0        Referral  Consideration
#
#           AdSpend  ClickThroughRate  ConversionRate  WebsiteVisits  \
# ...

# %% [markdown]
# Data Preprocessing

# %%
import pandas as pd

df=pd.read_csv("light_spotify_dataset.csv")

# %%
df.head()
# Out:
#   artist                   song  emotion  variance Genre  Release Date  \
# 0   ABBA  She's My Kind Of Girl      joy  0.447619   pop          2014
# 1   ABBA       Andante, Andante     love  0.202222   pop          1980
# 2   ABBA         As Good As New  sadness  0.300881   pop          1979
# 3   ABBA                   Bang      joy  0.355000   pop          1975
# 4   ABBA       Bang-A-Boomerang      joy  0.355000   pop          1975
#
#       Key  Tempo  Loudness Explicit  Popularity  Energy  Danceability  \
# 0   F Maj    128     -6.00       No          31      78            56
# 1  A# Maj    102    -10.72       No          59      36            52
# 2   E Maj    139     -5.70       No          50      78            85
# 3   F Maj    132     -3.00       No          52      76            50
# 4   F Maj    132     -3.00       No          52      76            50
#
#    Positiveness  Speechiness  Liveness  Acousticness  Instrumentalness
# ...

# %%
df.tail(10)
# Out:
#                               artist                 song  emotion  variance  \
# 236978                 (Olga Buzova)    Not Enough For Me      joy  0.833514
# 236979                (Jenia Lubich)         Russian Girl    anger  0.833514
# 236980                   (Ivan Dorn)               Afrika     love  0.833514
# 236981                   (Ivan Dorn)              Collaba      joy  0.833514
# 236982                   (Ivan Dorn)              Beverly      joy  0.833514
# 236983                  (Eri Sasaki)      Gate Of Steiner  sadness  0.833514
# 236984             (Elena Tsagrinou)            El Diablo     love  0.833514
# 236985                  (Dima Bilan)              Believe      joy  0.833514
# 236986                   (Ani Lorak)           Shady Lady      joy  0.833514
# 236987    (Alla Pugacheva) & 50 Cent  Позови меня P.I.M.P    anger  0.833514
#
#                           Genre  Release Date     Key  Tempo  Loudness  \
# ...

# %%
df.describe()
# Out:
#         CustomerID          Age         Income      AdSpend  ClickThroughRate  \
# count   8000.00000  8000.000000    8000.000000  8000.000000       8000.000000
# mean   11999.50000    43.625500   84664.196750  5000.944830          0.154829
# std     2309.54541    14.902785   37580.387945  2838.038153          0.084007
# min     8000.00000    18.000000   20014.000000   100.054813          0.010005
# 25%     9999.75000    31.000000   51744.500000  2523.221165          0.082635
# 50%    11999.50000    43.000000   84926.500000  5013.440044          0.154505
# 75%    13999.25000    56.000000  116815.750000  7407.989369          0.228207
# max    15999.00000    69.000000  149986.000000  9997.914781          0.299968
#
#        ConversionRate  WebsiteVisits  PagesPerVisit   TimeOnSite  \
# count     8000.000000    8000.000000    8000.000000  8000.000000
# mean         0.104389      24.751625       5.549299     7.727718
# std          0.054878      14.312269       2.607358     4.228218
# ...
