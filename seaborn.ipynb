# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df=sns.load_dataset('tips')

df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(x='total_bill',y='tip',data=df)
plt.title("Total bill vs Tip")
plt.show()

# %%
sns.barplot(data=df, x='day',y='total_bill',hue='time')
plt.show()

# %%
sns.barplot(data=df,x='day',y='total_bill',hue='sex',estimator='median')
plt.title("Total bill vs day")
plt.show()

# %%
sns.barplot(data=df,x='day',y='time',hue='smoker')
plt.show()

#this plot is not very meaningful better for counterplot

#Y axis as time not ideal for barplots

# %%
sns.barplot(data=df,x='time',y='tip',hue='sex')
plt.show()

# %%
#kde=kernel density estimate
#used to analyse the distribution of total bills

sns.histplot(data=df,x='total_bill',kde=True)
plt.show()

# %% [markdown]
# 📊 1. barplot()
# ✅ Purpose:
# To compare average values (like mean or median) of a numerical variable across categories.
#
# 🧠 How it works:
# Aggregates the data for each category (e.g., average total bill per day).
#
# Plots vertical or horizontal bars representing these aggregates.
#
# 🔧 Key Parameters:
# x: categorical variable (e.g., 'day')
#
# y: numerical variable (e.g., 'total_bill')
#
# hue: optional second category (e.g., 'sex')
#
# estimator: function like mean, median, sum
#
# 📈 2. histplot()
# ✅ Purpose:
# To visualize the distribution of a numerical variable.
#
# 🧠 How it works:
# Breaks the data into bins (intervals).
#
# Counts the number of values that fall into each bin.
#
# 🔧 Key Parameters:
# x: numerical column (e.g., 'price')
#
# hue: color separation by category (e.g., 'cut')
#
# kde: show smooth density curve
#
# multiple: how multiple hues are shown ('stack', 'dodge')
#
# 📌 Use Cases:
# Use Case	Example
# See distribution shape	How diamond prices are distributed
# Compare groups	Age distribution by passenger class
# Detect skewness/outliers	Check if income is right-skewed
#
# 📍 3. scatterplot()
# ✅ Purpose:
# To visualize the relationship between two numerical variables.
#
# 🧠 How it works:
# Plots each data point using its x and y values as coordinates.
#
# 🔧 Key Parameters:
# x: numeric variable for horizontal axis
#
# y: numeric variable for vertical axis
#
# hue: third variable mapped to color
#
# size, style: optional additional dimensions
#
# 📌 Use Cases:
# Use Case	Example
# Identify correlations	Do higher bills lead to higher tips?
# Visualize clusters	Grouping in customer spending
# Detect patterns	Outliers, trends, relationships

# %%
sns.histplot(data=df,x='total_bill',hue='sex',multiple='stack')
plt.title("Total bill vs Day")
plt.show()

# %%
df2=sns.load_dataset('titanic')
sns.histplot(data=df2,x='age',kde=True,hue='class')
plt.show()

# %%
df3=sns.load_dataset('diamonds')

sns.histplot(data=df3,x='price',hue='cut',kde=True,multiple='stack')
plt.title("price histogram")
plt.show()

# %%
sns.violinplot(data=df3,x='cut',y='depth',palette='coolwarm')
plt.title("Price Distribution by Diamond Color")
plt.show()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_16076\2140351567.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df3,x='cut',y='depth',palette='coolwarm')
